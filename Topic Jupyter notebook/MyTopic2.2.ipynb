# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('C:/Science/Magistr/AI/dataset.csv')
# Out:
# C:\ProgramsMy\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3,4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#          id    spkid       full_name pdes     name prefix neo pha     H  \
# 0  a0000001  2000001         1 Ceres    1    Ceres    NaN   N   N  3.40
# 1  a0000002  2000002        2 Pallas    2   Pallas    NaN   N   N  4.20
# 2  a0000003  2000003          3 Juno    3     Juno    NaN   N   N  5.33
# 3  a0000004  2000004         4 Vesta    4    Vesta    NaN   N   N  3.00
# 4  a0000005  2000005       5 Astraea    5  Astraea    NaN   N   N  6.90
#
#    diameter  ...       sigma_i      sigma_om       sigma_w      sigma_ma  \
# 0   939.400  ...  4.608900e-09  6.168800e-08  6.624800e-08  7.820700e-09
# 1   545.000  ...  3.469400e-06  6.272400e-06  9.128200e-06  8.859100e-06
# 2   246.596  ...  3.223100e-06  1.664600e-05  1.772100e-05  8.110400e-06
# 3   525.400  ...  2.170600e-07  3.880800e-07  1.789300e-07  1.206800e-06
# 4   106.699  ...  2.740800e-06  2.894900e-05  2.984200e-05  8.303800e-06
#
#        sigma_ad       sigma_n      sigma_tp     sigma_per  class      rms
# ...

# %%
df["H"].hist()
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(df["H"])
# Out:
# C:\ProgramsMy\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='H'>

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'spkid'}>,
#         <AxesSubplot:title={'center':'H'}>,
#         <AxesSubplot:title={'center':'diameter'}>,
#         <AxesSubplot:title={'center':'albedo'}>,
#         <AxesSubplot:title={'center':'diameter_sigma'}>,
#         <AxesSubplot:title={'center':'epoch'}>],
#        [<AxesSubplot:title={'center':'epoch_mjd'}>,
#         <AxesSubplot:title={'center':'epoch_cal'}>,
#         <AxesSubplot:title={'center':'e'}>,
#         <AxesSubplot:title={'center':'a'}>,
#         <AxesSubplot:title={'center':'q'}>,
#         <AxesSubplot:title={'center':'i'}>],
#        [<AxesSubplot:title={'center':'om'}>,
#         <AxesSubplot:title={'center':'w'}>,
#         <AxesSubplot:title={'center':'ma'}>,
#         <AxesSubplot:title={'center':'ad'}>,
#         <AxesSubplot:title={'center':'n'}>,
#         <AxesSubplot:title={'center':'tp'}>],
#        [<AxesSubplot:title={'center':'tp_cal'}>,
#         <AxesSubplot:title={'center':'per'}>,
# ...

# %%
df["neo"].value_counts().head()
# Out:
# N    935625
# Y     22895
# Name: neo, dtype: int64

# %%
sns.countplot(df["neo"])
# Out:
# C:\ProgramsMy\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='neo', ylabel='count'>

# %%
sns.countplot(df[df["neo"].isin(df["neo"].value_counts().head().index)]["neo"]);
# Out:
# C:\ProgramsMy\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
feat = [f for f in df.columns if "diameter" in f]

df[feat].hist()
# Out:
# array([[<AxesSubplot:title={'center':'diameter'}>,
#         <AxesSubplot:title={'center':'diameter_sigma'}>]], dtype=object)

# %%
sns.pairplot(df[feat])

# %%
# df["neo"] = df["neo"].map({"N":False, "Y":True})
# df["neo"].map({False:"danger", True:"not_danger"}).head()

# %%
plt.scatter(
    df[df["a"]]["diametr"],
    df[df["a"]]["H"],
    color = "orange",
    label  = "a"
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-d51fd541e1fb> in <module>
#       1 plt.scatter(
# ----> 2     df[df["a"]]["diametr"],
#       3     df[df["a"]]["H"],
#       4     color = "orange",
#       5     label  = "a"
#
# C:\ProgramsMy\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# C:\ProgramsMy\Anaconda\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df.drop(feat, axis =1, inplace = True)
sns.heatmap(df.corr())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-1623470a10b1> in <module>
# ----> 1 df.drop(feat, axis =1, inplace = True)
#       2 sns.heatmap(df.corr())
#
# C:\ProgramsMy\Anaconda\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# C:\ProgramsMy\Anaconda\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...
