# %%
import pandas as pd
import numpy as np

dataset = pd.read_csv('C:\Science\Delete\dataset.csv')

dataset.head()
# Out:
# C:\ProgramsMy\Python\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (3,4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          id    spkid       full_name pdes     name prefix neo pha     H  \
# 0  a0000001  2000001         1 Ceres    1    Ceres    NaN   N   N  3.40
# 1  a0000002  2000002        2 Pallas    2   Pallas    NaN   N   N  4.20
# 2  a0000003  2000003          3 Juno    3     Juno    NaN   N   N  5.33
# 3  a0000004  2000004         4 Vesta    4    Vesta    NaN   N   N  3.00
# 4  a0000005  2000005       5 Astraea    5  Astraea    NaN   N   N  6.90
#
#    diameter  ...       sigma_i      sigma_om       sigma_w      sigma_ma  \
# 0   939.400  ...  4.608900e-09  6.168800e-08  6.624800e-08  7.820700e-09
# 1   545.000  ...  3.469400e-06  6.272400e-06  9.128200e-06  8.859100e-06
# 2   246.596  ...  3.223100e-06  1.664600e-05  1.772100e-05  8.110400e-06
# ...

# %%
print(dataset.shape) #строки, столбцы
# Out:
# (958524, 45)

# %%
print(dataset.columns)
# Out:
# Index(['id', 'spkid', 'full_name', 'pdes', 'name', 'prefix', 'neo', 'pha', 'H',
#        'diameter', 'albedo', 'diameter_sigma', 'orbit_id', 'epoch',
#        'epoch_mjd', 'epoch_cal', 'equinox', 'e', 'a', 'q', 'i', 'om', 'w',
#        'ma', 'ad', 'n', 'tp', 'tp_cal', 'per', 'per_y', 'moid', 'moid_ld',
#        'sigma_e', 'sigma_a', 'sigma_q', 'sigma_i', 'sigma_om', 'sigma_w',
#        'sigma_ma', 'sigma_ad', 'sigma_n', 'sigma_tp', 'sigma_per', 'class',
#        'rms'],
#       dtype='object')

# %%
print(dataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 958524 entries, 0 to 958523
# Data columns (total 45 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              958524 non-null  object
#  1   spkid           958524 non-null  int64
#  2   full_name       958524 non-null  object
#  3   pdes            958524 non-null  object
#  4   name            22064 non-null   object
#  5   prefix          18 non-null      object
#  6   neo             958520 non-null  object
#  7   pha             938603 non-null  object
#  8   H               952261 non-null  float64
#  9   diameter        136209 non-null  float64
#  10  albedo          135103 non-null  float64
#  11  diameter_sigma  136081 non-null  float64
#  12  orbit_id        958524 non-null  object
#  13  epoch           958524 non-null  float64
#  14  epoch_mjd       958524 non-null  int64
#  15  epoch_cal       958524 non-null  float64
# ...

# %%
dataset['spkid'] = dataset['spkid'].astype('float')

# %%
print(dataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 958524 entries, 0 to 958523
# Data columns (total 45 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              958524 non-null  object
#  1   spkid           958524 non-null  float64
#  2   full_name       958524 non-null  object
#  3   pdes            958524 non-null  object
#  4   name            22064 non-null   object
#  5   prefix          18 non-null      object
#  6   neo             958520 non-null  object
#  7   pha             938603 non-null  object
#  8   H               952261 non-null  float64
#  9   diameter        136209 non-null  float64
#  10  albedo          135103 non-null  float64
#  11  diameter_sigma  136081 non-null  float64
#  12  orbit_id        958524 non-null  object
#  13  epoch           958524 non-null  float64
#  14  epoch_mjd       958524 non-null  int64
#  15  epoch_cal       958524 non-null  float64
# ...

# %%
dataset['spkid'] = dataset['spkid'].astype('int64')

# %%
print(dataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 958524 entries, 0 to 958523
# Data columns (total 45 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              958524 non-null  object
#  1   spkid           958524 non-null  int64
#  2   full_name       958524 non-null  object
#  3   pdes            958524 non-null  object
#  4   name            22064 non-null   object
#  5   prefix          18 non-null      object
#  6   neo             958520 non-null  object
#  7   pha             938603 non-null  object
#  8   H               952261 non-null  float64
#  9   diameter        136209 non-null  float64
#  10  albedo          135103 non-null  float64
#  11  diameter_sigma  136081 non-null  float64
#  12  orbit_id        958524 non-null  object
#  13  epoch           958524 non-null  float64
#  14  epoch_mjd       958524 non-null  int64
#  15  epoch_cal       958524 non-null  float64
# ...

# %%
dataset.describe()
# Out:
#          id    spkid       full_name pdes     name prefix neo pha     H  \
# 0  a0000001  2000001         1 Ceres    1    Ceres    NaN   N   N  3.40
# 1  a0000002  2000002        2 Pallas    2   Pallas    NaN   N   N  4.20
# 2  a0000003  2000003          3 Juno    3     Juno    NaN   N   N  5.33
# 3  a0000004  2000004         4 Vesta    4    Vesta    NaN   N   N  3.00
# 4  a0000005  2000005       5 Astraea    5  Astraea    NaN   N   N  6.90
#
#    diameter  ...       sigma_i      sigma_om       sigma_w      sigma_ma  \
# 0   939.400  ...  4.608900e-09  6.168800e-08  6.624800e-08  7.820700e-09
# 1   545.000  ...  3.469400e-06  6.272400e-06  9.128200e-06  8.859100e-06
# 2   246.596  ...  3.223100e-06  1.664600e-05  1.772100e-05  8.110400e-06
# 3   525.400  ...  2.170600e-07  3.880800e-07  1.789300e-07  1.206800e-06
# 4   106.699  ...  2.740800e-06  2.894900e-05  2.984200e-05  8.303800e-06
#
#        sigma_ad       sigma_n      sigma_tp     sigma_per  class      rms
# ...

# %%
dataset.head()
# Out:
#          id    spkid       full_name pdes     name prefix neo pha     H  \
# 0  a0000001  2000001         1 Ceres    1    Ceres    NaN   N   N  3.40
# 1  a0000002  2000002        2 Pallas    2   Pallas    NaN   N   N  4.20
# 2  a0000003  2000003          3 Juno    3     Juno    NaN   N   N  5.33
# 3  a0000004  2000004         4 Vesta    4    Vesta    NaN   N   N  3.00
# 4  a0000005  2000005       5 Astraea    5  Astraea    NaN   N   N  6.90
#
#    diameter  ...       sigma_i      sigma_om       sigma_w      sigma_ma  \
# 0   939.400  ...  4.608900e-09  6.168800e-08  6.624800e-08  7.820700e-09
# 1   545.000  ...  3.469400e-06  6.272400e-06  9.128200e-06  8.859100e-06
# 2   246.596  ...  3.223100e-06  1.664600e-05  1.772100e-05  8.110400e-06
# 3   525.400  ...  2.170600e-07  3.880800e-07  1.789300e-07  1.206800e-06
# 4   106.699  ...  2.740800e-06  2.894900e-05  2.984200e-05  8.303800e-06
#
#        sigma_ad       sigma_n      sigma_tp     sigma_per  class      rms
# ...

# %%
dataset.describe()
# Out:
#               spkid              H       diameter         albedo  \
# count  9.585240e+05  952261.000000  136209.000000  135103.000000
# mean   3.810114e+06      16.906411       5.506429       0.130627
# std    6.831541e+06       1.790405       9.425164       0.110323
# min    2.000001e+06      -1.100000       0.002500       0.001000
# 25%    2.239632e+06      16.100000       2.780000       0.053000
# 50%    2.479262e+06      16.900000       3.972000       0.079000
# 75%    3.752518e+06      17.714000       5.765000       0.190000
# max    5.401723e+07      33.200000     939.400000       1.000000
#
#        diameter_sigma         epoch      epoch_mjd     epoch_cal  \
# count   136081.000000  9.585240e+05  958524.000000  9.585240e+05
# mean         0.479184  2.458869e+06   58868.781950  2.019693e+07
# std          0.782895  7.016716e+02     701.671573  1.930354e+04
# min          0.000500  2.425052e+06   25051.000000  1.927062e+07
# ...

# %%
dataset.describe(include=['object','bool'])
# Out:
#               id           full_name        pdes        name prefix     neo  \
# count     958524              958524      958524       22064     18  958520
# unique    958524              958524      958524       22064      1       2
# top     bK14Wq5W         (2015 PU56)  2014 DF166  Shawnzhang      A       N
# freq           1                   1           1           1     18  935625
#
#            pha orbit_id equinox   class
# count   938603   958524  958524  958524
# unique       2     4690       1      13
# top          N        1   J2000     MBA
# freq    936537    50142  958524  855954

# %%
dataset['diameter'].value_counts()#вывод определнного значения
# Out:
# 3.296      45
# 4.017      45
# 3.377      44
# 3.537      44
# 3.008      44
#            ..
# 102.565     1
# 26.799      1
# 42.550      1
# 48.480      1
# 14.734      1
# Name: diameter, Length: 16591, dtype: int64

# %%
dataset.sort_values(by = 'diameter', ascending = False).head()#False - по убываению
# Out:
#              id    spkid                   full_name   pdes    name prefix  \
# 0      a0000001  2000001                     1 Ceres      1   Ceres    NaN
# 19999  a0020000  2020000   20000 Varuna (2000 WR106)  20000  Varuna    NaN
# 1      a0000002  2000002                    2 Pallas      2  Pallas    NaN
# 3      a0000004  2000004                     4 Vesta      4   Vesta    NaN
# 9      a0000010  2000010                   10 Hygiea     10  Hygiea    NaN
#
#       neo pha    H  diameter  ...       sigma_i      sigma_om       sigma_w  \
# 0       N   N  3.4    939.40  ...  4.608900e-09  6.168800e-08  6.624800e-08
# 19999   N   N  3.6    900.00  ...  5.648800e-05  6.101800e-05  1.617400e-02
# 1       N   N  4.2    545.00  ...  3.469400e-06  6.272400e-06  9.128200e-06
# 3       N   N  3.0    525.40  ...  2.170600e-07  3.880800e-07  1.789300e-07
# 9       N   N  5.5    407.12  ...  2.173400e-06  2.855200e-05  3.023700e-05
#
# ...

# %%
dataset.sort_values(by = 'diameter', ascending = True).head()#True - по возрастаию
# Out:
#               id    spkid            full_name        pdes name prefix neo  \
# 736313  bK12XB2B  3620672         (2012 XB112)  2012 XB112  NaN    NaN   Y
# 673103  bK10G07H  3515028           (2010 GH7)    2010 GH7  NaN    NaN   Y
# 672267  bK10F06D  3512348           (2010 FD6)    2010 FD6  NaN    NaN   Y
# 676545  bK10K07V  3523338           (2010 KV7)    2010 KV7  NaN    NaN   Y
# 672287  bK10F09R  3512698           (2010 FR9)    2010 FR9  NaN    NaN   Y
#
#        pha     H  diameter  ...   sigma_i  sigma_om   sigma_w  sigma_ma  \
# 736313   N  29.9    0.0025  ...  0.000081  0.000315  0.000902  0.002026
# 673103   N  27.3    0.0080  ...  0.026473  0.091124  0.295740  0.992720
# 672267   N  26.8    0.0080  ...  0.001244  0.018584  0.015398  0.123310
# 676545   N  26.0    0.0130  ...  0.003363  0.012558  0.006954  0.212730
# 672287   N  26.1    0.0150  ...  0.004586  0.010417  0.053099  0.924610
#
#         sigma_ad   sigma_n  sigma_tp  sigma_per  class      rms
# ...

# %%
dataset['diameter'].mean()#как я понял выводит среднее
# Out:
# 5.506429057551376

# %%
dataset[dataset['diameter']>5].mean()
# Out:
# spkid             2.107332e+06
# prefix                     NaN
# H                 1.399655e+01
# diameter          1.014141e+01
# albedo            9.570994e-02
# diameter_sigma    4.816967e-01
# epoch             2.458996e+06
# epoch_mjd         5.899595e+04
# epoch_cal         2.020042e+07
# e                 1.367516e-01
# a                 3.105264e+00
# q                 2.663728e+00
# i                 1.129516e+01
# om                1.702536e+02
# w                 1.815136e+02
# ma                1.810309e+02
# ad                3.546800e+00
# n                 1.913395e-01
# tp                2.459012e+06
# tp_cal            2.020007e+07
# per               2.142496e+03
# per_y             5.865835e+00
# moid              1.682792e+00
# moid_ld           6.548921e+02
# sigma_e           6.748073e-03
# sigma_a           3.620616e-02
# sigma_q           4.548713e-02
# sigma_i           5.065140e-02
# sigma_om          2.294300e-01
# sigma_w           4.011934e+00
# ...

# %%
dataset[-1:]
# Out:
#               id    spkid          full_name      pdes name prefix neo pha  \
# 958523  bT3S2678  3246553         (2678 T-3)  2678 T-3  NaN    NaN   N   N
#
#             H  diameter  ...  sigma_i  sigma_om sigma_w  sigma_ma  sigma_ad  \
# 958523  18.06       NaN  ...   1.1023    0.3117  1.2843   0.47361   0.16267
#
#          sigma_n sigma_tp  sigma_per  class     rms
# 958523  0.024879   5.5236     106.48    MBA  0.2698
#
# [1 rows x 45 columns]

# %%
total_calls = dataset['diameter']+dataset['e']
dataset.head()
# Out:
#          id    spkid       full_name pdes     name prefix neo pha     H  \
# 0  a0000001  2000001         1 Ceres    1    Ceres    NaN   N   N  3.40
# 1  a0000002  2000002        2 Pallas    2   Pallas    NaN   N   N  4.20
# 2  a0000003  2000003          3 Juno    3     Juno    NaN   N   N  5.33
# 3  a0000004  2000004         4 Vesta    4    Vesta    NaN   N   N  3.00
# 4  a0000005  2000005       5 Astraea    5  Astraea    NaN   N   N  6.90
#
#    diameter  ...       sigma_i      sigma_om       sigma_w      sigma_ma  \
# 0   939.400  ...  4.608900e-09  6.168800e-08  6.624800e-08  7.820700e-09
# 1   545.000  ...  3.469400e-06  6.272400e-06  9.128200e-06  8.859100e-06
# 2   246.596  ...  3.223100e-06  1.664600e-05  1.772100e-05  8.110400e-06
# 3   525.400  ...  2.170600e-07  3.880800e-07  1.789300e-07  1.206800e-06
# 4   106.699  ...  2.740800e-06  2.894900e-05  2.984200e-05  8.303800e-06
#
#        sigma_ad       sigma_n      sigma_tp     sigma_per  class      rms
# ...
