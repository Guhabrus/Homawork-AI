# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('C:/Science/Magistr/AI/dataset.csv')
# Out:
# C:\ProgramsMy\Python\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (3,4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#          id    spkid       full_name pdes     name prefix neo pha     H  \
# 0  a0000001  2000001         1 Ceres    1    Ceres    NaN   N   N  3.40
# 1  a0000002  2000002        2 Pallas    2   Pallas    NaN   N   N  4.20
# 2  a0000003  2000003          3 Juno    3     Juno    NaN   N   N  5.33
# 3  a0000004  2000004         4 Vesta    4    Vesta    NaN   N   N  3.00
# 4  a0000005  2000005       5 Astraea    5  Astraea    NaN   N   N  6.90
#
#    diameter  ...       sigma_i      sigma_om       sigma_w      sigma_ma  \
# 0   939.400  ...  4.608900e-09  6.168800e-08  6.624800e-08  7.820700e-09
# 1   545.000  ...  3.469400e-06  6.272400e-06  9.128200e-06  8.859100e-06
# 2   246.596  ...  3.223100e-06  1.664600e-05  1.772100e-05  8.110400e-06
# 3   525.400  ...  2.170600e-07  3.880800e-07  1.789300e-07  1.206800e-06
# 4   106.699  ...  2.740800e-06  2.894900e-05  2.984200e-05  8.303800e-06
#
#        sigma_ad       sigma_n      sigma_tp     sigma_per  class      rms
# ...

# %% [markdown]
# # признаки по одному

# %%
df['H'].hist()
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(df['H'])
# Out:
# C:\ProgramsMy\Python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='H'>

# %%
df.hist();

# %% [markdown]
# # Категориальные признаки

# %%
df['name'].value_counts()
# Out:
# Ceres           1
# Amytang         1
# Marcelleroux    1
# Dusser          1
# Kurosaki        1
#                ..
# Messenger       1
# Zahnle          1
# Lhasa           1
# Bolotov         1
# 'Oumuamua       1
# Name: name, Length: 22064, dtype: int64

# %%
df['prefix'].value_counts().head()
# Out:
# A    18
# Name: prefix, dtype: int64

# %%
sns.countplot(df['neo']);
# Out:
# C:\ProgramsMy\Python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Взаимодействие количественных признаков

# %%
priznak = [f for f in df.columns if 'H' in f] #нахождение признаков с именем H'

# %%
priznak
# Out:
# ['H']

# %%
df[priznak].hist() #гистошграмма только по найденным признаку
# Out:
# array([[<AxesSubplot:title={'center':'H'}>]], dtype=object)

# %%
sns.pairplot(df[priznak]);

# %%
plt.scatter(df['sigma_i'], df['sigma_om'], color=df['sigma_i'].)# диаграмма рассеяния
plt.xlabel('хз чё по x');
plt.ylabel('хз чё по y');

# %%
df.corr()# корреляция (вроде бы Пирсона???)
# Out:
#                    spkid         H  diameter    albedo  diameter_sigma  \
# spkid           1.000000  0.146075 -0.095362 -0.179656        0.023419
# H               0.146075  1.000000 -0.572648 -0.221658       -0.070651
# diameter       -0.095362 -0.572648  1.000000 -0.108880        0.337145
# albedo         -0.179656 -0.221658 -0.108880  1.000000       -0.080525
# diameter_sigma  0.023419 -0.070651  0.337145 -0.080525        1.000000
# epoch           0.006816 -0.175712  0.058475  0.094071       -0.005169
# epoch_mjd       0.006816 -0.175712  0.058475  0.094071       -0.005169
# epoch_cal       0.006999 -0.176349  0.058539  0.094114       -0.005120
# e               0.010951  0.345334 -0.050649 -0.020403       -0.016542
# a               0.000116 -0.032187  0.146799 -0.114484        0.206718
# q              -0.002115 -0.437429  0.329223 -0.267607        0.381335
# i               0.013443 -0.099022  0.054963 -0.086802        0.039580
# ...

# %%
sns.heatmap(df.corr());

# %%
df.drop(priznak, axis = 1)
# Out:
#               id    spkid          full_name      pdes     name prefix neo  \
# 0       a0000001  2000001            1 Ceres         1    Ceres    NaN   N
# 1       a0000002  2000002           2 Pallas         2   Pallas    NaN   N
# 2       a0000003  2000003             3 Juno         3     Juno    NaN   N
# 3       a0000004  2000004            4 Vesta         4    Vesta    NaN   N
# 4       a0000005  2000005          5 Astraea         5  Astraea    NaN   N
# ...          ...      ...                ...       ...      ...    ...  ..
# 958519  bPLS6013  3246801         (6013 P-L)  6013 P-L      NaN    NaN   N
# 958520  bPLS6331  3246834         (6331 P-L)  6331 P-L      NaN    NaN   N
# 958521  bPLS6344  3013075         (6344 P-L)  6344 P-L      NaN    NaN   Y
# 958522  bT2S2060  3246457         (2060 T-2)  2060 T-2      NaN    NaN   N
# 958523  bT3S2678  3246553         (2678 T-3)  2678 T-3      NaN    NaN   N
#
# ...

# %% [markdown]
# # Взаимодействие кооличественного и категориального признака

# %%
sns.boxplot(x = 'neo', y = 'H', data = df) #сравннение различных признаков
# Out:
# <AxesSubplot:xlabel='neo', ylabel='H'>

# %%
sns.boxplot(x = 'name', y = 'H', data = df.head())
# Out:
# <AxesSubplot:xlabel='name', ylabel='H'>

# %%
sns.violinplot(x = 'neo', y = 'H', data = df)
# Out:
# <AxesSubplot:xlabel='neo', ylabel='H'>

# %%
df.groupby('sigma_i')['H'].mean() #группируем по наклонению и считаем среднее по H
# Out:
# sigma_i
# 4.608900e-09     3.4000
# 4.087800e-08    10.4000
# 1.548100e-07    11.4000
# 1.903000e-07    15.2000
# 1.949900e-07    19.2000
#                  ...
# 3.515900e+04     6.3995
# 3.904400e+04     7.0792
# 3.981700e+04     7.4277
# 4.549400e+04    18.1000
# 5.533000e+04    16.1110
# Name: H, Length: 215741, dtype: float64

# %% [markdown]
# # Сравнение категориального признака с категориальном

# %%
pd.crosstab(df['H'], df['diameter'])
# Out:
# diameter  0.0025    0.0080    0.0130    0.0150    0.0180    0.0190    \
# H
# 3.0              0         0         0         0         0         0
# 3.4              0         0         0         0         0         0
# 3.6              0         0         0         0         0         0
# 4.2              0         0         0         0         0         0
# 5.2              0         0         0         0         0         0
# ...            ...       ...       ...       ...       ...       ...
# 26.8             0         1         0         0         0         0
# 27.0             0         0         0         0         0         1
# 27.3             0         1         0         0         0         0
# 27.5             0         0         0         0         1         0
# 29.9             1         0         0         0         0         0
#
# diameter  0.0230    0.0240    0.0260    0.0280    ...  270.3270  302.0000  \
# H                                                 ...
# ...

# %%
sns.countplot(x = 'neo', hue = 'pha', data = df);
